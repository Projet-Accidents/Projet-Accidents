# %%
# Étape 1 : Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git config --global user.email "machalagune@gmail.com"
# !git config --global user.name "Macha"

# %%
# !git clone https://github.com/Projet-Accidents/Projet-Accidents.git /content/drive/MyDrive/Datascientest/Github1
# Out:
# Cloning into '/content/drive/MyDrive/Datascientest/Github1'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (1/1), done.

# %%
# Copier le dossier depuis Google Drive vers le répertoire local
import shutil
shutil.copytree("/content/drive/MyDrive/Datascientest/Projet_accidents/Dataset/2019_2023/Github","./Github",dirs_exist_ok=True)
# Out:
# './Github'

# %%
#Vérifier si le dépôt GitHub est cloné
# Le dépôt est cloné dans '/content/drive/MyDrive/Datascientest/Github1', donc on va s'assurer de bien se positionner dans ce dossier
import os
os.chdir('/content/drive/MyDrive/Datascientest/Github1')

# %%
# Chemin du dossier source sur Google Drive
source_folder = '/content/drive/MyDrive/Datascientest/Projet_accidents/Dataset/2019_2023/Github'

# Chemin du dépôt cloné sur Google Drive
destination_folder = '/content/drive/MyDrive/Datascientest/Github1'

# Copier le contenu du dossier source dans le dépôt cloné
shutil.copytree(source_folder, destination_folder, dirs_exist_ok=True)

print(f"Le contenu du dossier {source_folder} a été copié dans {destination_folder}")
# Out:
# Le contenu du dossier /content/drive/MyDrive/Datascientest/Projet_accidents/Dataset/2019_2023/Github a été copié dans /content/drive/MyDrive/Datascientest/Github1

# %%
# Vérifier l'état des fichiers
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Ajouter les fichiers au dépôt
# !git add .

# %%
# Commit des modifications
# !git commit -m "Ajout du dossier depuis Google Drive"
# Out:
# [main 7148807] Ajout du dossier depuis Google Drive
#  102 files changed, 9541254 insertions(+)
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2005.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2006.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2007.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2008.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2009.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2010.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2011.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2012.csv"
#  create mode 100644 "1. Datasets/Caracte\314\201ristiques_2005_2023/caracteristiques_2013.csv"
# ...

# %%
# !git remote -v
# Out:
# origin	https://github.com/Projet-Accidents/Projet-Accidents.git (fetch)
# origin	https://github.com/Projet-Accidents/Projet-Accidents.git (push)

# %%
# Pousser les modifications vers GitHub
# !git push https://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@github.com/Projet-Accidents/Projet-Accidents.git
# Out:
# Enumerating objects: 116, done.
# Counting objects: 100% (116/116), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (115/115), done.
# Writing objects: 100% (115/115), 123.68 MiB | 2.58 MiB/s, done.
# Total 115 (delta 20), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (20/20), done.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File 4. Modèles_Machine_Learning/df_machine_learning.csv is 51.90 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/Projet-Accidents/Projet-Accidents.git
#    ab1af38..7148807  main -> main
